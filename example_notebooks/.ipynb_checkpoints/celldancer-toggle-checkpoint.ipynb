# %%
import celldancer as cd
import anndata
import pandas as pd
import numpy as np
import scipy as sp
import os

# %%
adata = anndata.read_h5ad('../data/toggle_switch/data_toggle.h5ad')

# %%
adata.layers['Mu']=adata.layers['unspliced']
adata.layers['Ms']=adata.layers['spliced']

# %%
df = cd.adata_to_df_with_embed(adata,
                               cell_type_para='leiden',
                               embed_para='coord')
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00, 26.35it/s]

# %%
df_loss , df = cd.velocity(df)
# Out:
# Using /Users/cliffzhou/Documents/GitHub/scTT/example_notebooks/cellDancer_velocity_2023-07-22 16-18-40 as the output path.
# Arranging genes for parallel job.
# 2  genes were arranged to  1  portion.
# Velocity Estimation:   0%|          | 0/1 [00:00<?, ?it/s]
# Velocity Estimation: 100%|██████████| 1/1 [00:09<00:00,  9.12s/it]

# %%
df
# Out:
#        cellIndex gene_name  unsplice    splice  unsplice_predict  \
# 0              0    gene_B  0.000000  0.000000          1.562898
# 1              1    gene_B  0.000823  0.000000          1.565719
# 2              2    gene_B  0.003715  0.000082          1.575645
# 3              3    gene_B  0.005473  0.001027          1.581605
# 4              4    gene_B  0.002728  0.000000          1.572261
# ...          ...       ...       ...       ...               ...
# 20015      10005    gene_A  0.018584  0.740491          2.844646
# 20016      10006    gene_A  0.028149  0.718070          2.879417
# 20017      10007    gene_A  0.000000  0.999182          2.750400
# 20018      10008    gene_A  0.001210  0.975858          2.757283
# 20019      10009    gene_A  0.008850  0.969770          2.782977
#
#        splice_predict     alpha      beta     gamma      loss cellID clusters  \
# 0            0.000000  1.016350  1.823612  2.067193  0.069461      0        0
# 1            0.001866  1.017808  1.823528  2.067101  0.069461      1        0
# 2            0.008504  1.022940  1.823237  2.066782  0.069461      2        0
# 3            0.013392  1.026012  1.823070  2.066600  0.069461      3        0
# 4            0.006188  1.021191  1.823336  2.066890  0.069461      4        0
# ...               ...       ...       ...       ...       ...    ...      ...
# 20015        0.746684  1.054663  3.267252  3.352736  0.062167  10005        1
# 20016        0.745521  1.065133  3.265938  3.352011  0.062167  10006        1
# 20017        0.954359  1.024377  3.272085  3.355859  0.062167  10007        1
# 20018        0.934653  1.026627  3.271702  3.355604  0.062167  10008        1
# 20019        0.945051  1.034218  3.270786  3.355121  0.062167  10009        1
#
#        embedding1  embedding2
# 0       10.978738    0.000000
# 1       11.583890    0.000000
# 2       11.725379    0.000082
# 3       12.061873    0.001027
# 4       12.334953    0.000000
# ...           ...         ...
# 20015    0.740491   12.596205
# 20016    0.718070   12.869117
# 20017    0.999182   12.815824
# 20018    0.975858   12.770738
# 20019    0.969770   11.805122
#
# [20020 rows x 14 columns]

# %%
df = cd.compute_cell_velocity(df)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6,6))
im = cd.cdplt.scatter_cell(ax,
                        df, 
                        colors=['0','1'], 
                        alpha=0.3, 
                        s=10,
                        velocity=True)
ax.axis('off')
plt.show()
