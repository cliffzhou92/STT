# %% [markdown]
# # Analysis of Mouse Brain Spatial Data

# %%
import stt as st
import scanpy as sc
import anndata
import scvelo as scv
import gseapy as gp
import numpy as np
import pandas as pd
from scipy.cluster.hierarchy import linkage, fcluster
import matplotlib as mpl
from adjustText import adjust_text
# Out:
# /home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/pyemma/__init__.py:92: UserWarning: You are not using the latest release of PyEMMA. Latest is 2.5.7, you have 2.5.6.
#   .format(latest=latest, current=current), category=UserWarning)

# %% [markdown]
# The processed data could be download [here](https://drive.google.com/file/d/1c53v1xo0wPd_2O7Zkfz1SWYsrv6e5bUC/view?usp=drive_link)

# %%
data_dir = '../data/'
adata1 = sc.read_h5ad(data_dir+'E8-10_b_S21.h5ad')
adata2 = sc.read_h5ad(data_dir+'E8-10_b_S22.h5ad')

# %%
sc.pl.embedding(adata1, basis='spatial', color='anno_cell_type')

# %%
sc.pl.embedding(adata1, basis='spatial', color='anno_germ_layer')

# %%
sc.pp.highly_variable_genes(adata1, flavor='seurat_v3', n_top_genes=2000)
adata1.raw = adata1
adata1 = adata1[:, adata1.var.highly_variable]
# Out:
# /home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/scanpy/preprocessing/_highly_variable_genes.py:64: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   UserWarning,

# %%
scv.pp.moments(adata1,n_neighbors=50)
# Out:
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# Normalized count data: spliced, unspliced.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
scv.pp.moments(adata,n_neighbors=100)
# Out:
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# Normalized count data: spliced, unspliced.
# computing neighbors
#     finished (0:00:20) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:06) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
adata1.layers['Ms'].max()
# Out:
# 12.749408

# %%
adata1.obs['attractor']= adata1.obs['anno_germ_layer'].values

adata_aggr = st.tl.dynamical_iteration(adata1,n_states = 5, n_iter = 15, return_aggr_obj=True, weight_connectivities = 0.5,n_components = 21, n_neighbors = 100,thresh_ms_gene = 0.2, use_spatial = True,spa_weight = 0.3, thresh_entropy = 0.05)
# Out:
#   0%|          | 0/1086 [00:00<?, ?cell/s]
# [0]PETSC ERROR: ------------------------------------------------------------------------
# [0]PETSC ERROR: Caught signal number 13 Broken Pipe: Likely while reading or writing to a socket
# [0]PETSC ERROR: Try option -start_in_debugger or -on_error_attach_debugger
# [0]PETSC ERROR: or see https://petsc.org/release/faq/#valgrind
# [0]PETSC ERROR: or try http://valgrind.org on GNU/linux and Apple MacOS to find memory corruption errors
# Fatal Python error: GC object already tracked
#
# Current thread 0x00007f76dc94e640 (most recent call first):
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/connection.py", line 368 in _send
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing[DESKTOP-07JEJMM:34484] *** Process received signal ***
# /connection.py", line 404 in _send_bytes
#   File [DESKTOP-07JEJMM:34484] Signal: Aborted (6)
# [DESKTOP-07JEJMM:34484] Signal code:  (-6)
# "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/connection.py", line 206 in send
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/managers.py", line 207 in handle_request
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 870 in run
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 926 in _bootstrap_inner
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 890 in _bootstrap
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py", line 1118 in __call__
#
# Thread 0x00007f76dd14f640 (most recent call first):
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/socket.py", line 212 in accept
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/connection.py", line 598 in accept
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/connection.py", line 453 in accept
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/managers.py", line 178 in accepter
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 870 in run
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 926 in _bootstrap_inner
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 890 in _bootstrap
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py", line 1118 in __call__
#
# Thread 0x00007f76af810640 (most recent call first):
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 300 in wait
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 552 in wait
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 261 in _on_run
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 49 in run
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 926 in _bootstrap_inner
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 890 in _bootstrap
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py", line 1118 in __call__
#
# Thread 0x00007f76b6ffd640 (most recent call first):
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 300 in wait
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 552 in wait
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 215 in _on_run
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 49 in run
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 926 in _bootstrap_inner
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 890 in _bootstrap
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py", line 1118 in __call__
#
# Thread 0x00007f76b77fe640 (most recent call first):
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 204 in _read_line
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 222 in _on_run
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 49 in run
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 926 in _bootstrap_inner
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 890 in _bootstrap
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py", line 1118 in __call__
#
# Thread 0x00007f76b7fff640 (most recent call first):
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 300 in wait
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/queue.py", line 179 in get
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py", line 368 in _on_run
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_daemon_thread.py", line 49 in run
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 926 in _bootstrap_inner
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/threading.py", line 890 in _bootstrap
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py", line 1118 in __call__
#
# Thread 0x00007f79496d6740 (most recent call first):
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 943 in _internal_get_file_type
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 1050 in get_file_type
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/util.py", line 268 in <listcomp>
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/util.py", line 268 in _run_finalizers
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/util.py", line 311 in _exit_function
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/process.py", line 300 in _bootstrap
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/popen_fork.py", line 74 in _launch
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/popen_fork.py", line 20 in __init__
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/context.py", line 277 in _Popen
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/process.py", line 112 in start
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/managers.py", line 563 in start
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/multiprocessing/context.py", line 56 in Manager
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/cellrank/ul/_parallelize.py", line 94 in wrapper
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/cellrank/tl/kernels/_velocity_kernel.py", line 356 in _run_in_parallel
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/cellrank/tl/kernels/_velocity_kernel.py", line 560 in <lambda>
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/cellrank/ul/_utils.py", line 279 in wrapper
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/cellrank/tl/kernels/_velocity_kernel.py", line 276 in compute_transition_matrix
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/cellrank/tl/_transition_matrix.py", line 83 in compute_velocity_kernel
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/cellrank/tl/_transition_matrix.py", line 88 in transition_matrix
#   File "/mnt/d/OneDrive/\u6587\u6863/GitHub/STT/example_notebooks/stt/tl/_dynamical_analysis.py", line 49 in dynamical_analysis
#   File "/mnt/d/OneDrive/\u6587\u6863/GitHub/STT/example_notebooks/stt/tl/_dynamical_analysis.py", line 277 in dynamical_iteration
#   File "/tmp/ipykernel_800/734110752.py", line 3 in <module>
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3553 in run_code
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3473 in run_ast_nodes
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3258 in run_cell_async
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78 in _pseudo_sync_runner
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3030 in _run_cell
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2976 in run_cell
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 528 in run_cell
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 387 in do_execute
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 730 in execute_request
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 406 in dispatch_shell
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 499 in process_one
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 510 in dispatch_queue
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/asyncio/events.py", line 88 in _run
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/asyncio/base_events.py", line 1782 in _run_once
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/asyncio/base_events.py", line 538 in run_forever
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 215 in start
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 712 in start
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/traitlets/config/application.py", line 1043 in launch_instance
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/ipykernel_launcher.py", line 17 in <module>
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/runpy.py", line 85 in _run_code
#   File "/home/cliffzhou/miniconda3/envs/stt/lib/python3.7/runpy.py", line 193 in _run_module_as_main
#   0%|          | 0/1086 [00:00<?, ?cell/s]
# [0]PETSC ERROR: ------------------------------------------------------------------------
# [0]PETSC ERROR: Caught signal number 13 Broken Pipe: Likely while reading or writing to a socket
# [0]PETSC ERROR: Try option -start_in_debugger or -on_error_attach_debugger
# [0]PETSC ERROR: or see https://petsc.org/release/faq/#valgrind
# [0]PETSC ERROR: or try http://valgrind.org on GNU/linux and Apple MacOS to find memory corruption errors
# [0]PETSC ERROR: configure using --with-debugging=yes, recompile, link, and run
# [0]PETSC ERROR: to get more information on the crash.
# [0]PETSC ERROR: ------------------------------------------------------------------------
# [0]PETSC ERROR: Caught signal number 11 SEGV: Segmentation Violation, probably memory access out of range
# [0]PETSC ERROR: Try option -start_in_debugger or -on_error_attach_debugger
# [0]PETSC ERROR: or see https://petsc.org/release/faq/#valgrind
# [0]PETSC ERROR: or try http://valgrind.org on GNU/linux and Apple MacOS to find memory corruption errors
# [0]PETSC ERROR: configure using --with-debugging=yes, recompile, link, and run
# [0]PETSC ERROR: to get more information on the crash.
# [0]PETSC ERROR: Run with -malloc_debug to check if memory corruption is causing the crash.
# WARNING: KNN graph is not symmetric (0:00:00)
# WARNING: Detected `16` absorbing states in the transition matrix. This matrix won't be irreducible.
# ((0.7 * ((0.5 * <VelocityKernel[softmax_scale=nan, mode=deterministic, seed=60039, scheme=<DotProductScheme>]>) + (0.5 * <ConnectivityKernel[dnorm=True, key=connectivities]>))) + (0.3 * <ConnectivityKernel[dnorm=True, key=spatial_connectivities]>))
# WARNING: Computing transition matrix using the default parameters
#
# Quantiles for entropy relative difference with last iteration:
# 0.00   NaN
# 0.25   NaN
# 0.50   NaN
# 0.75   NaN
# 1.00   NaN
# dtype: float64
#
# Quantiles for entropy absolute difference with last iteration:
# 0.00    0.119443
# 0.25    0.916348
# 0.50    1.049901
# 0.75    1.201092
# 1.00    1.469507
# dtype: float64
#
# Quantiles for entropy absolute difference with last iteration:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_800/734110752.py in <module>
#       1 adata1.obs['attractor']= adata1.obs['anno_germ_layer'].values
#       2
# ----> 3 adata_aggr = st.tl.dynamical_iteration(adata1,n_states = 5, n_iter = 15, return_aggr_obj=True, weight_connectivities = 0.5,n_components = 21, n_neighbors = 100,thresh_ms_gene = 0.2, use_spatial = True,spa_weight = 0.3, thresh_entropy = 0.05)
#
# /mnt/d/OneDrive/文档/GitHub/STT/example_notebooks/stt/tl/_dynamical_analysis.py in dynamical_iteration(adata, n_states, n_states_seq, n_iter, return_aggr_obj, weight_connectivities, n_components, n_neighbors, thresh_ms_gene, thresh_entropy, use_spatial, spa_weight, spa_conn_key, monitor_mode)
#     273         entropy_orig = entropy
#     274
# --> 275         sc.tl.pca(sc_object_aggr,use_highly_variable = True)
#     276         sc.pp.neighbors(sc_object_aggr,n_neighbors = n_neighbors)
#     277         dynamical_analysis(adata, sc_object_aggr, n_states = n_states,n_states_seq=n_states_seq, weight_connectivities=weight_connectivities, n_components = n_components,thresh_ms_gene = thresh_ms_gene, use_spatial = use_spatial, spa_weight = spa_weight, spa_conn_key = spa_conn_key)
#
# ~/miniconda3/envs/stt/lib/python3.7/site-packages/scanpy/preprocessing/_pca.py in pca(data, n_comps, zero_center, svd_solver, random_state, return_info, use_highly_variable, dtype, copy, chunked, chunk_size)
#     186             n_components=n_comps, svd_solver=svd_solver, random_state=random_state
#     187         )
# --> 188         X_pca = pca_.fit_transform(X)
#     189     elif issparse(X) and zero_center:
#     190         from sklearn.decomposition import PCA
#
# ~/miniconda3/envs/stt/lib/python3.7/site-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     374         C-ordered array, use 'np.ascontiguousarray'.
#     375         """
# --> 376         U, S, V = self._fit(X)
#     377         U = U[:, :self.n_components_]
#     378
#
# ~/miniconda3/envs/stt/lib/python3.7/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     396
#     397         X = self._validate_data(X, dtype=[np.float64, np.float32],
# --> 398                                 ensure_2d=True, copy=self.copy)
#     399
#     400         # Handle n_components==None
#
# ~/miniconda3/envs/stt/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~/miniconda3/envs/stt/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/miniconda3/envs/stt/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     659                              " a minimum of %d is required%s."
#     660                              % (n_features, array.shape, ensure_min_features,
# --> 661                                 context))
#     662
#     663     if copy and np.may_share_memory(array, array_orig):
#
# ValueError: Found array with 0 feature(s) (shape=(1086, 0)) while a minimum of 1 is required.

# %%
sc.pl.embedding(adata1, basis="spatial", color="attractor")

# %%
st.pl.plot_top_genes(adata1, top_genes = 100, ncols =8, wspace = 1, hspace = 1, figsize = (12,20),color='membership',attractor=6)

# %%
adata_aggr
# Out:
# AnnData object with n_obs × n_vars = 7765 × 182
#     obs: 'entropy', 'attractor', 'speed'
#     var: 'highly_variable'
#     uns: 'pca', 'neighbors', 'T_fwd_params', 'eig_fwd', 'gene_subset'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'velocity', 'spliced', 'Ms'
#     obsp: 'distances', 'connectivities', 'T_fwd'

# %%
#import importlib
#importlib.reload(st.pl)

st.pl.plot_genes_list(adata, genelist = ['Lrrtm4'], figsize =(10,10) ,ncols =1, wspace = 0.9, hspace = 1)
#plt.savefig('./figures/emt_genes.pdf',dpi = 800,bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_39281/3642923721.py in <module>
#       2 #importlib.reload(st.pl)
#       3
# ----> 4 st.pl.plot_genes_list(adata, genelist = ['Lrrtm4'], figsize =(10,10) ,ncols =1, wspace = 0.9, hspace = 1,color='membership',attractor=2)
#       5 #plt.savefig('./figures/emt_genes.pdf',dpi = 800,bbox_inches = 'tight')
#
# TypeError: plot_genes_list() got an unexpected keyword argument 'color'

# %%
sc.set_figure_params(dpi=600,fontsize = 12)
mpl.rcParams['axes.grid'] = False
adata_aggr.obsm['X_spatial']=adata.obsm['X_spatial']
adata_aggr.obsm['X_spatial_aggr']=adata.obsm['X_spatial']
adata.obsm['X_spatial_aggr'] = adata.obsm['X_spatial']
st.pl.plot_tensor(adata, adata_aggr, basis = 'spatial', list_attractor = [0,1,2],filter_cells = True, member_thresh = 0.1)

# %%
st.pl.plot_tensor(adata, adata_aggr, basis = 'spatial', list_attractor = [3,4,5],filter_cells = True, member_thresh = 0.1)
# Out:
# View of AnnData object with n_obs × n_vars = 7765 × 91
#     obs: 'area', 'n_counts', 'Size_Factor', 'initial_cell_size', 'louvain', 'scc', 'scc_anno', 'attractor', 'entropy', 'speed'
#     var: 'pass_basic_filter', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'r2_train', 'r2_test'
#     uns: '__type', 'louvain', 'louvain_colors', 'neighbors', 'pp', 'scc', 'spatial', 'spatial_neighbors', 'hvg', 'da_out', 'par', 'r2_keep_train', 'r2_keep_test', 'gene_subset', 'attractor_colors'
#     obsm: 'X_pca', 'X_spatial', 'bbox', 'contour', 'spatial', 'tensor_v', 'tensor_v_aver', 'rho'
#     layers: 'count', 'spliced', 'unspliced', 'Ms', 'Mu', 'velo'
#     obsp: 'connectivities', 'distances', 'spatial_connectivities', 'spatial_distances'
# check that the input includes aggregated object
# computing velocity graph (using 32/32 cores)
#   0%|          | 0/7765 [00:00<?, ?cells/s]
# /home/cliffzhou/miniconda3/envs/stt/lib/python3.7/site-packages/scvelo/core/_parallelize.py:138: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   res = np.array(res) if as_array else res
#     finished (0:00:06) --> added
#     'vj_graph', sparse matrix with cosine correlations (adata.uns)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_34477/1947426721.py in <module>
# ----> 1 st.pl.plot_tensor(adata, adata_aggr, basis = 'spatial', list_attractor = [3,4,5],filter_cells = True, member_thresh = 0.1)
#
# /mnt/d/OneDrive/文档/GitHub/STT/example_notebooks/stt/pl/_plot_tensor.py in plot_tensor(adata, adata_aggr, list_state, list_attractor, basis, figsize, hspace, wspace, color_map, size, alpha, filter_cells, member_thresh)
#      63             ax = plt.subplot(nrows, ncols, fig_id)
#      64             fig_id+=1
# ---> 65             plot_tensor_single(adata, adata_aggr, attractor = attractor, state = state, basis = basis_plot,ax = ax,show = False, member_thresh = member_thresh, filter_cells = filter_cells, size = size, alpha = alpha)
#
# /mnt/d/OneDrive/文档/GitHub/STT/example_notebooks/stt/pl/_plot_tensor.py in plot_tensor_single(adata, adata_aggr, state, attractor, basis, color, color_map, size, alpha, ax, show, filter_cells, member_thresh)
#      40         adata_aggr.layers['vj'] = np.concatenate((velo[:,gene_select,0],velo[:,gene_select,1]),axis = 1)
#      41         scv.tl.velocity_graph(adata_aggr, vkey = 'vj', xkey = 'Ms',n_jobs = -1)
# ---> 42         scv.pl.velocity_embedding_stream(adata_aggr, vkey = 'vj',basis=basis, color=color, title = title+','+'Joint',color_map = color_map, size = size, alpha = alpha, ax = ax, show = show)
#      43
#      44
#
# ~/miniconda3/envs/stt/lib/python3.7/site-packages/scvelo/plotting/velocity_embedding_stream.py in velocity_embedding_stream(adata, basis, vkey, density, smooth, min_mass, cutoff_perc, arrow_color, arrow_size, arrow_style, max_length, integration_direction, linewidth, n_neighbors, recompute, color, use_raw, layer, color_map, colorbar, palette, size, alpha, perc, X, V, X_grid, V_grid, sort_order, groups, components, legend_loc, legend_fontsize, legend_fontweight, xlabel, ylabel, title, fontsize, figsize, dpi, frameon, show, save, ax, ncols, **kwargs)
#     140         )
#     141         comps, obsm = get_components(components, basis), _adata.obsm
# --> 142         X_emb = np.array(obsm[f"X_{basis}"][:, comps]) if X is None else X[:, :2]
#     143         V_emb = np.array(obsm[f"{vkey}_{basis}"][:, comps]) if V is None else V[:, :2]
#     144         X_grid, V_grid = compute_velocity_on_grid(
#
# ~/miniconda3/envs/stt/lib/python3.7/site-packages/anndata/_core/aligned_mapping.py in __getitem__(self, key)
#     146
#     147     def __getitem__(self, key: str) -> V:
# --> 148         return self._data[key]
#     149
#     150     def __setitem__(self, key: str, value: V):
#
# KeyError: 'X_spatial'

# %%
st.plot_tensor(adata, adata_aggr, basis = 'xy_loc', list_attractor = [6,7],filter_cells = True, member_thresh = 0.1)

# %%
sc.set_figure_params(dpi=600,fontsize = 12)
import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
st.plot_tensor_single(adata, adata_aggr,  basis = 'xy_loc', state = 'joint',attractor = 2,filter_cells = True, member_thresh = 0.1)

# %%
st.plot_tensor_single(adata, adata_aggr,  basis = 'xy_loc', state = 'joint',attractor = 1,filter_cells = True, member_thresh = 0.1)

# %%
st.plot_tensor_single(adata, adata_aggr,  basis = 'umap', state = 'unspliced',attractor = 1,filter_cells = True, member_thresh = 0.2)

# %%
st.plot_tensor_single(adata, adata_aggr,  basis = 'umap', state = 'unspliced',attractor = 2,filter_cells = True, member_thresh = 0.2)

# %%
st.plot_tensor_single(adata, adata_aggr,  basis = 'xy_loc', state = 'joint',attractor = None,filter_cells = True, member_thresh = 0.2)

# %%
st.plot_tensor_single(adata, adata_aggr,  basis = 'xy_loc', state = 'spliced',attractor = None,filter_cells = True, member_thresh = 0.2)

# %%
st.plot_tensor_single(adata, adata_aggr,  basis = 'xy_loc', state = 'unspliced',attractor = None,filter_cells = True, member_thresh = 0.2)

# %%
sc.pl.violin(adata, keys = ['entropy'], groupby='attractor')

# %%
st.construct_landscape(adata, coord_key = 'xy_loc')

# %%
sc.set_figure_params(dpi=600,figsize = (6,6) ,fontsize = 10)
st.infer_lineage(adata,si=0,sf=2, method = 'MPPT',flux_fraction=0.6)

# %%
# %matplotlib inline
sc.set_figure_params(dpi=600,figsize = (4,4) ,fontsize = 10)
st.plot_landscape(adata, dim = 3, elev=57, azim = 167,size_point = 8)

# %%
ms_genes = adata.uns['gene_subset']
adata.uns['gene_subset'] = [x for x in ms_genes if x.startswith('Wnt')]
adata_aggr.uns['gene_subset'] = [x for x in ms_genes if x.startswith('Wnt')]

# %%
st.plot_tensor(adata, adata_aggr, basis = 'xy_loc', list_attractor = [3,4,5],filter_cells = True, member_thresh = 0.1)

# %% [markdown]
# ## Pathway Analysis

# %%
pathway = gp.parser.download_library(name = 'KEGG_2019_Mouse')

# %%
tpm_dict = {}
pathway_select = {}
temp = []
for key in pathway.keys():
    gene_list = [x.capitalize() for x in pathway[key]] 
    gene_select = [x for x in gene_list if x in adata_aggr.var_names]
    if len(gene_select)>2 and gene_select not in temp:
            scv.tl.velocity_graph(adata, vkey = 'vj', xkey = 'Ms', gene_subset = gene_select ,n_jobs = -1)
            tpm_dict[key] = adata.uns['vj_graph'].toarray().reshape(-1)
            pathway_select[key] = gene_select
            temp.append(gene_select)

# %%
import numpy as np
import pandas as pd
import umap
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Create a pandas DataFrame from the dictionary
arr = np.stack(list(tpm_dict.values()))
cor = np.corrcoef(arr)

# %%
pca = PCA(n_components=10)
pca_embedding = pca.fit_transform(cor)

# Perform UMAP on the PCA embedding
umap_reducer = umap.UMAP()
umap_embedding = umap_reducer.fit_transform(pca_embedding)

# %%
# Perform hierarchical clustering
linked = linkage(cor, method='ward')

# Define the distance threshold or desired number of clusters
# Here, we'll use a distance threshold of 1.5
threshold = 1.5

# Get clustering labels as a NumPy array
c_labels = fcluster(linked, threshold, criterion='distance')

# %%
# Sample data
x = umap_embedding[:, 0]
y = umap_embedding[:, 1]
labels = tpm_dict.keys()

# Create the scatter plot
fig, ax = plt.subplots()

num_clusters = max(c_labels)
cmap = plt.cm.get_cmap('Set2', num_clusters)

# Map the labels to colors using the colormap
colors = cmap((c_labels - 1) / (num_clusters - 1))

# Plot the scatter plot with colors based on the labels
sc = plt.scatter(x, y, c=colors)

# Remove the square outline
for spine in ['top','right']:
    ax.spines[spine].set_visible(False)


arrow_properties = dict(
    arrowstyle='->',  # Simple arrow with a head
    color='red',      # Arrow color
    linewidth=0.5,    # Arrow line width
    alpha=0.8,         # Arrow transparency     
    mutation_scale=5 
)
# Annotate points with labels
texts = []
for i, txt in enumerate(labels):
    texts.append(ax.annotate(txt, (x[i], y[i]), fontsize=8))
    
# Adjust the annotation positions to avoid overlaps
adjust_text(texts,arrowprops=arrow_properties)

# Hide axis ticks
ax.set_xticks([])
ax.set_yticks([])

# Hide axis labels (tick labels)
plt.xlabel('Embedding 1')
plt.ylabel('Embedding 2')

# Display the plot
plt.show()

# %%
subset = pathway_select['TGF-beta signaling pathway']
adata.uns['gene_subset'] = subset
adata_aggr.uns['gene_subset'] = subset+[x+'_u' for x in subset]
st.plot_tensor_single(adata, adata_aggr, basis = 'xy_loc', state= 'joint')

# %%
subset = pathway_select['Wnt signaling pathway']
adata.uns['gene_subset'] = subset
adata_aggr.uns['gene_subset'] = subset+[x+'_u' for x in subset]
st.plot_tensor_single(adata, adata_aggr, basis = 'xy_loc', state= 'joint')

# %%
subset = pathway_select['MAPK signaling pathway']
adata.uns['gene_subset'] = subset
adata_aggr.uns['gene_subset'] = subset+[x+'_u' for x in subset]
st.plot_tensor_single(adata, adata_aggr, basis = 'xy_loc', state= 'joint')

# %%
subset = pathway_select['Hippo signaling pathway']
adata.uns['gene_subset'] = subset
adata_aggr.uns['gene_subset'] = subset+[x+'_u' for x in subset]
st.plot_tensor_single(adata, adata_aggr, basis = 'xy_loc', state= 'joint')
